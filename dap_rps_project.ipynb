# %%
while True:
    player1 = input('Hello Player 1. Please enter one of the choices: rock, paper, or scissors')
    player2 = input('Hello Player 2. Please enter one of the choices: rock, paper, or scissors')
    
    
    if player1 == player2:
        print("It's a tie!")

    elif player1 == 'rock' and player2 == 'scissors':
        print('Player 1 wins! Rock beats scissors!')

    elif player1 == 'rock' and player2 == 'paper':
        print('Player 2 wins! Paper covers rock!')

    elif player1 == 'paper' and player2 == 'rock':
        print('Player 1 wins! Paper covers rock')

    elif player1 == 'paper' and player2 == 'scissors':
        print('Player 2 wins! Scissors cut paper!')

    elif player1 == 'scissors' and player2 == 'paper':
        print('Player 1 wins! Scissors cut paper!')

    elif player1 == 'scissors' and player2 == 'rock':
        print('Player 2 wins! Rock beats scissors!')
    
    play_again = input('Would you like to play again? Enter Yes or No')
    
    if play_again == 'No':
        print('Game End')
        break
# Out:
# Hello Player 1. Please enter one of the choices: rock, paper, or scissors Scissors
# Hello Player 2. Please enter one of the choices: rock, paper, or scissors Rock
# Would you like to play again? Enter Yes or No no
# Hello Player 1. Please enter one of the choices: rock, paper, or scissors scissors
# Hello Player 2. Please enter one of the choices: rock, paper, or scissors paper
# Player 1 wins! Scissors cut paper!
# Would you like to play again? Enter Yes or No Yes
# Hello Player 1. Please enter one of the choices: rock, paper, or scissors paper
# Hello Player 2. Please enter one of the choices: rock, paper, or scissors rock
# Player 1 wins! Paper covers rock
# Would you like to play again? Enter Yes or No y
# Hello Player 1. Please enter one of the choices: rock, paper, or scissors rock
# Hello Player 2. Please enter one of the choices: rock, paper, or scissors paper
# Player 2 wins! Paper covers rock!
# Would you like to play again? Enter Yes or No no
# ...
